# %% [markdown]
# ## 5 number Summary And Box Plot

# %%
## Minimum,MAximum,Median,Q1,Q3,IQR

# %%
import numpy as np

# %%
lst_marks = [45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]

# %%
minimum,Q1,median,Q3,maximum = np.quantile(lst_marks,[0,0.25,0.5,0.75,1.0])

# %%
Q1,Q3
# Out:
# (np.float64(54.0), np.float64(89.0))

# %%
IQR = Q3-Q1

# %%
IQR ## inter-quartile-Range
# Out:
# np.float64(35.0)

# %%
# outlier boundary
lower_bound = Q1-1.5*IQR
upper_bound = Q3+1.5*IQR

# %%
lower_bound,upper_bound
# Out:
# (np.float64(1.5), np.float64(141.5))

# %%
import seaborn as sns
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks = [-50,-100,45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,200,190]

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >
